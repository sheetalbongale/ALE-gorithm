# %% [markdown]
# ## Data Wrangling and Cleaning
# The CSV file for beer reviews dataset is too large to get on GitHub. So trying to drop any unwanted data.

# %%
# Dependencies and packages
# %reload_ext lab_black

import os
import pandas as pd
import numpy as np
import math as math
import datetime as dt

# %%
csv_path = os.path.join("../data/beer_reviews.csv")
df = pd.read_csv(csv_path)

df.head(30)
# Out:
#     brewery_id             brewery_name  review_time  review_overall  \
# 0        10325          Vecchio Birraio   1234817823             1.5
# 1        10325          Vecchio Birraio   1235915097             3.0
# 2        10325          Vecchio Birraio   1235916604             3.0
# 3        10325          Vecchio Birraio   1234725145             3.0
# 4         1075  Caldera Brewing Company   1293735206             4.0
# 5         1075  Caldera Brewing Company   1325524659             3.0
# 6         1075  Caldera Brewing Company   1318991115             3.5
# 7         1075  Caldera Brewing Company   1306276018             3.0
# 8         1075  Caldera Brewing Company   1290454503             4.0
# 9         1075  Caldera Brewing Company   1285632924             4.5
# 10         163   Amstel Brouwerij B. V.   1010963392             3.0
# 11        1075  Caldera Brewing Company   1283154365             5.0
# 12        1075  Caldera Brewing Company   1277557990             4.0
# ...

# %%
df.dtypes
# Out:
# brewery_id              int64
# brewery_name           object
# review_time             int64
# review_overall        float64
# review_aroma          float64
# review_appearance     float64
# review_profilename     object
# beer_style             object
# review_palate         float64
# review_taste          float64
# beer_name              object
# beer_abv              float64
# beer_beerid             int64
# dtype: object

# %%
df.shape
# Out:
# (1586614, 13)

# %% [markdown]
# ## Find the number of unique breweries

# %%
df["brewery_name"].value_counts()
# Out:
# Boston Beer Company (Samuel Adams)    39444
# Dogfish Head Brewery                  33839
# Stone Brewing Co.                     33066
# Sierra Nevada Brewing Co.             28751
# Bell's Brewery, Inc.                  25191
#                                       ...
# Brauerei zum Schwarzen Adler              1
# Ouray Brewery                             1
# Birrificio Baüscia                        1
# Docks                                     1
# The Famous Railway Tavern Brewery         1
# Name: brewery_name, Length: 5742, dtype: int64

# %% [markdown]
# #### Drop all rows that have NaN or ratings less than 2.5: Because we won't recommend these beers to anyone.
# Although we might need these for some visualizations to show analytical insights

# %%
df_clean = df.dropna(how="any")

# %%
#df_clean.drop(df[df["review_overall"] < 2.5].index, inplace=True)

# %%
#df_clean.to_csv(os.path.join("../data/beer_reviews_clean.csv"))

# %% [markdown]
# File is still large.

# %% [markdown]
# ### Try the other dataset thats 2GB

# %%
csv_path2 = os.path.join("../data/reviews.csv")
df2 = pd.read_csv(csv_path2)

# %%
df2.head()
# Out:
#    beer_id         username        date  \
# 0   271781     bluejacket74  2017-03-17
# 1   125646          _dirty_  2017-12-21
# 2   125646          CJDUBYA  2017-12-21
# 3   125646  GratefulBeerGuy  2017-12-20
# 4   125646         LukeGude  2017-12-20
#
#                                                 text  look  smell  taste  \
# 0     750 ml bottle, 2016 vintage, bottle #304 of...  4.00   4.00   4.00
# 1                                                     4.50   4.50   4.50
# 2                                                     4.75   4.75   4.75
# 3     0% 16 oz can. Funny story: As I finally wal...  4.75   4.75   4.50
# 4     Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50   4.25
#
#    feel  overall  score
# 0  4.25     4.00   4.03
# 1  4.50     4.50   4.50
# 2  4.75     4.75   4.75
# 3  4.50     4.50   4.58
# 4  4.25     4.25   4.31

# %%
df2.shape
# Out:
# (9073128, 10)

# %%
# Find the number of unique breweries
df2["beer_id"].value_counts()
# Out:
# 11757     17160
# 2093      15947
# 7971      14927
# 1093      14915
# 29619     14292
#           ...
# 203777        1
# 126326        1
# 109950        1
# 282050        1
# 8188          1
# Name: beer_id, Length: 309542, dtype: int64

# %%
df2.drop(df2[df2["score"] < 4].index, inplace=True)
df2.shape
# Out:
# (4785625, 10)

# %% [markdown]
# ## Back to analysis beers_reviews.csv DF

# %% [markdown]
# ### Find Unique Beer types

# %%
df_clean["beer_style"].value_counts()
# Out:
# American IPA                        113144
# American Double / Imperial IPA       85105
# American Pale Ale (APA)              58072
# Russian Imperial Stout               53424
# American Double / Imperial Stout     50137
#                                      ...
# English Pale Mild Ale                  648
# Faro                                   608
# Roggenbier                             395
# Happoshu                               237
# Kvass                                  229
# Name: beer_style, Length: 104, dtype: int64

# %%
df_clean.shape
# Out:
# (1518478, 13)
