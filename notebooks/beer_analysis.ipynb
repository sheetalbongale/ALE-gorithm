# %% [markdown]
# ## Beer Analysis
# Notebook to get insights from the datasets for beers and breweries

# %%
# Dependencies and packages
# %load_ext lab_black

import os
import pandas as pd
import numpy as np
import math as math
import datetime as dt

# %%
csv_path = os.path.join("../data/beers.csv")
df = pd.read_csv(csv_path)

df.head(30)
# Out:
#         id                                   name  brewery_id state country  \
# 0   202522                         Olde Cogitator        2199    CA      US
# 1    82352   Konrads Stout Russian Imperial Stout       18604   NaN      NO
# 2   214879                         Scottish Right       44306    IN      US
# 3   320009                MegaMeow Imperial Stout        4378    WA      US
# 4   246438                        Peaches-N-Cream       44617    PA      US
# 5     8036                   World Burp Beer 2002        3469   NaN      JP
# 6   108605                            Icon Sender       22598    CA      US
# 7   345382                             Divina IPA       45567   NaN      IT
# 8   255286                    Light Of The Ozarks       11203    AR      US
# 9    29556                         Warrior's Bock        8203    SK      CA
# 10  106840                 Firehouse Coffee Stout       25251   NaN      AU
# 11  253234                  Coffee Infused Bitter       46862    WA      US
# 12   15271                      Belgian Style Wit        1345    WA      US
# 13   69212                          Réserve No. 3       18796    QC      CA
# 14  181442        Southern Saints India Wheat Ale       33659    NC      US
# 15  351259                        Champagne Toast       34416    WA      US
# 16  303023  The Sky Is High (wet Hopped Pale Ale)       46616    NJ      US
# 17  265827                                Addison       30870    PA      US
# 18  219798                      Ocean Barley Wine       16420   NaN      SE
# 19  110318                           Schwartz Hop       22598    CA      US
# 20  262655                       Stove By A Whale       45045    MA      US
# 21   15645                          Cerveza India         846   NaN      PR
# 22  123597                    Bojan Wielkopolskie       35034   NaN      PL
# 23  138971                                 Porter       34412    NC      US
# 24  368953                             Sneaky Raz       46938    GA      US
# 25   31135                               Rock Ice        1491   NaN      CR
# 26  199068                     Eastwood - Equinox       33278    CA      US
# 27  165236                                Fortuna          30    CO      US
# 28   80010      Joy Division Series: No Love Lost       25186    PA      US
# 29  337139                              Walshtown       17089    SD      US
#
#                       style            availability   abv  \
# 0     English Oatmeal Stout                Rotating   7.3
# 1    Russian Imperial Stout                Rotating  10.4
# 2              Scottish Ale              Year-round   4.0
# 3   American Imperial Stout                  Winter   8.7
# 4        American Cream Ale                Rotating   5.1
# 5       Japanese Rice Lager   Limited (brewed once)   5.5
# 6            American Lager              Year-round   5.6
# 7              American IPA                Rotating   6.5
# 8            American Lager                Rotating   4.3
# 9               German Bock                Rotating   7.5
# 10            English Stout   Limited (brewed once)   5.0
# 11           English Bitter                Rotating   3.5
# 12          Belgian Witbier              Year-round   4.5
# 13      American Strong Ale   Limited (brewed once)  11.8
# 14  American Pale Wheat Ale                  Spring   6.9
# 15          Berliner Weisse                Rotating   4.0
# 16  American Pale Ale (APA)   Limited (brewed once)   5.2
# 17  American Pale Ale (APA)                Rotating   5.5
# 18       British Barleywine              Year-round   9.8
# 19       American Black Ale   Limited (brewed once)   6.0
# 20            Baltic Porter              Year-round   7.4
# 21   American Adjunct Lager              Year-round   NaN
# 22      European Pale Lager              Year-round   5.0
# 23          American Porter                Rotating   5.3
# 24     Fruit and Field Beer   Limited (brewed once)   6.5
# 25   American Adjunct Lager              Year-round   4.7
# 26    American Imperial IPA   Limited (brewed once)   8.2
# 27        American Wild Ale   Limited (brewed once)   8.1
# 28       American Black Ale   Limited (brewed once)   7.8
# 29            Irish Red Ale                Rotating   5.3
#
#                                                 notes retired
# 0                              No notes at this time.       f
# 1                              No notes at this time.       f
# 2                              No notes at this time.       t
# 3                                Every time this year       f
# 4                              No notes at this time.       f
# 5                              No notes at this time.       t
# 6                              No notes at this time.       f
# 7                              No notes at this time.       f
# 8                              No notes at this time.       f
# 9                              No notes at this time.       t
# 10                             No notes at this time.       t
# 11                             No notes at this time.       f
# 12                             No notes at this time.       t
# 13                             No notes at this time.       t
# 14                             No notes at this time.       f
# 15                             No notes at this time.       f
# 16  This hazy pale ale is brewed with fresh Cascad...       t
# 17                             No notes at this time.       f
# 18                             No notes at this time.       f
# 19                             No notes at this time.       t
# 20                             No notes at this time.       f
# 21                             No notes at this time.       t
# 22                             No notes at this time.       f
# 23                             No notes at this time.       f
# 24                             No notes at this time.       f
# 25                             No notes at this time.       f
# 26                             No notes at this time.       t
# 27  Sour ale that is aged in Tequila barrels with ...       t
# 28                             No notes at this time.       t
# 29                             No notes at this time.       f

# %%
csv_path2 = os.path.join("../data/breweries.csv")
df_breweries = pd.read_csv(csv_path2)

df_breweries.head(30)
# Out:
#        id                                               name  \
# 0   19730                                    Brouwerij Danny
# 1   32541                        Coachella Valley Brewing Co
# 2   44736                                   Beef 'O' Brady's
# 3   23372                             Broadway Wine Merchant
# 4   35328               Brighton Beer Dispensary (DUPLICATE)
# 5   31561                                     Teddy's Tavern
# 6   35975                         Modus Operandi Brewing Co.
# 7    5618                      Hops! Beer Restaurant & Pizza
# 8   30916                                    Kelly's Cellars
# 9   41278                                      The Other End
# 10  31711                                   Ten Bells Tavern
# 11  12324                     Bistro Europa / House Of Klaus
# 12  49850                                 Crafty's Beer Shop
# 13  16995                                   Le Bien, Le Malt
# 14  45715                    Angie's State Line Liquor Store
# 15  45617                                           Serafino
# 16  28685  Brasserie De Puisaye (La Ferme Des Grenouillet...
# 17  47633                                    Redneck Gourmet
# 18  31986                     Power Marketing / Wicked Pissa
# 19  47464                             Mahoney's Pub & Grille
# 20   8590                            Wet Planet Beverage Co.
# 21   8070                        Gasthausbrauerei Zum Alfons
# 22  26695                               Cervesera Tramuntana
# 23  53919                      Amity Ales Brewpub and Eatery
# 24  17834                                    The Crêpe Place
# 25  17675                                    McCray's Tavern
# 26  28200                                       Express Stop
# 27  48475                             Springdale Barrel Room
# 28  43654                                 Modist Brewing Co.
# 29  31006                                        Brasserie C
#
#                        city state country  \
# 0                 Erpe-Mere   NaN      BE
# 1            Thousand Palms    CA      US
# 2                Plant City    FL      US
# 3             Oklahoma City    OK      US
# 4                  Brighton   GB2      GB
# 5                   Seattle    WA      US
# 6                 Mona Vale   NaN      AU
# 7             Riccione (RN)   NaN      IT
# 8                   Belfast   GB5      GB
# 9                    Destin    FL      US
# 10                   Dallas    TX      US
# 11               Alexandria    VA      US
# 12  Letchworth Garden City
#    GB2      GB
# 13                 Rimouski    QC      CA
# 14                  Enfield    CT      US
# 15             Thessaloniki   NaN      GR
# 16              Saint-Privé   NaN      FR
# 17                   Newnan    GA      US
# 18                 Westport    MA      US
# 19                  Chicago    IL      US
# 20                    Utica    NY      US
# 21            Schwanenstadt   NaN      AT
# 22                    Palma   NaN      ES
# 23               Amityville    NY      US
# 24               Santa Cruz    CA      US
# 25                   Smyrna    GA      US
# 26            Bowling Green    OH      US
# 27               Framingham    MA      US
# 28              Minneapolis    MN      US
# 29                    Liège   NaN      BE
#
#                                                 notes  \
# 0                              No notes at this time.
# 1                              No notes at this time.
# 2                              No notes at this time.
# 3                              No notes at this time.
# 4   Duplicate of https://www.beeradvocate.com/beer...
# 5                              No notes at this time.
# 6                              No notes at this time.
# 7                              No notes at this time.
# 8                              No notes at this time.
# 9                              No notes at this time.
# 10                             No notes at this time.
# 11                             No notes at this time.
# 12                             No notes at this time.
# 13                             No notes at this time.
# 14                             No notes at this time.
# 15                             No notes at this time.
# 16                             No notes at this time.
# 17                             No notes at this time.
# 18                             No notes at this time.
# 19                             No notes at this time.
# 20                             No notes at this time.
# 21                             No notes at this time.
# 22                             No notes at this time.
# 23                             No notes at this time.
# 24                             No notes at this time.
# 25                             No notes at this time.
# 26                             No notes at this time.
# 27                             No notes at this time.
# 28  At Modist, we push past traditional brewing by...
# 29                             No notes at this time.
#
#                                types
# 0                            Brewery
# 1           Brewery, Bar, Beer-to-go
# 2                        Bar, Eatery
# 3                              Store
# 4                        Bar, Eatery
# 5                    Bar, Beer-to-go
# 6   Brewery, Bar, Eatery, Beer-to-go
# 7               Brewery, Bar, Eatery
# 8                                Bar
# 9                        Bar, Eatery
# 10                       Bar, Eatery
# 11                               Bar
# 12                   Bar, Beer-to-go
# 13              Brewery, Bar, Eatery
# 14                             Store
# 15                               Bar
# 16                           Brewery
# 17                       Bar, Eatery
# 18                           Brewery
# 19                       Bar, Eatery
# 20                           Brewery
# 21                   Brewery, Eatery
# 22              Brewery, Bar, Eatery
# 23              Brewery, Bar, Eatery
# 24                       Bar, Eatery
# 25                       Bar, Eatery
# 26                             Store
# 27                      Brewery, Bar
# 28          Brewery, Bar, Beer-to-go
# 29  Brewery, Bar, Eatery, Beer-to-go
